# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# <h1>My Jupyter Notebook on IBM Watson Studio<h1>

# %% [markdown]
# **Kostiantyn Kolisnyk**
#
# Quantitative trader

# %% [markdown]
# *I am interested in data science because it provides me with tools and skills to advance in my career and hobbies. Additionally, data science opens new career opportunities for me*

# %% [markdown]
# <h3>The code below will import "numpy" library, create the list "b" and using "numpy" it will create an array "b1" from list "b" and print "b1"<h3>

# %%
import numpy as np

b = [1, 2, 3, 4, 5, 6, 7]
b1 = np.array(b)
print(b1)
# Out:
# [1 2 3 4 5 6 7]

# %% [markdown]
# Cell 6 (rendered as Markdown): Using Markdown or HTML, this cell must include at least 3 of the following: horizontal rule, bulleted list, numbered list, tables, hyperlinks, images, code/syntax highlighting, blocked quotes, strikethrough.
#
# Numbered list
# 1. 1
# 2. 2
# 3. 3
#
#
#
# Table
# | Heading | Heading |
# | ----| ----|
# | text | text |
#
#
#
# Image
#
# ![Снимок экрана 2022-11-16 в 9.04.09 PM.png](attachment:7318cdcf-80ab-43b7-8125-8670df51ab83.png)
